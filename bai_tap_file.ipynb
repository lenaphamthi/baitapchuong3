# %% [markdown]
# <a href="https://colab.research.google.com/github/lenaphamthi/baitapchuong3/blob/main/bai_tap_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# bai 1

# %%
chuoi1 = input("Nhập 1 chuỗi: ")
tentep = input("Nhập tên tệp: ") + ".txt"
with open (tentep, "w") as f:
    f.write(chuoi1)
# Out:
# Nhập 1 chuỗi: hi world
# Nhập tên tệp: xin chao

# %% [markdown]
# bai 2

# %%
tentep = input("Nhập tên tệp: ") + ".txt"
with open (tentep, "r") as f:
    f.seek(0)
    tmp = f.read()
print(tmp)
# Out:
# Nhập tên tệp: xin chao
# hi world

# %% [markdown]
# bai 3

# %%
tenfile = input("Nhập tên tệp: ")
chuoi = input("Nhập chuỗi: ")
f = open(tenfile, 'a',)
f.write(chuoi)
f.close()
# Out:
# Nhập tên tệp: tạm biệt
# Nhập chuỗi: bye bye

# %% [markdown]
# bai 4

# %%
f = open(tenfile, 'r')
a = f.read()
print(a)
f.close()
# Out:
# bye bye

# %% [markdown]
# bai 5

# %%
import random
danhsach = []
check = 0
for i in range(1000):
    danhsach.append(random.randint(-1000, 1000))
filename = input("Tên file: ")
print(len(danhsach))
for i in danhsach:
    if check < 9:
        f = open(filename, 'a')
        chuoikytu = str(i)+','
        f.write(chuoikytu)
        f.close()
        check +=1
    else:
        f = open(filename, 'a')
        f.write(str(i)+"\n")
        f.close()
        check = 0
f = open(filename, 'r')
a = f.readlines()
for i in a:
    print(i.replace(",", "    "))
f.close()
# Out:
# Tên file: xin chao
# 1000
# 479    -571    -468    242    903    -933    -877    -950    -857    522
#
# -214    526    377    -965    728    -881    -423    165    -880    -489
#
# 841    -446    -583    -347    568    223    -69    -979    921    51
#
# 973    828    656    -661    -575    -239    -993    -899    -525    176
#
# -129    -773    572    529    942    204    444    403    -203    919
#
# -121    -616    -69    -625    -650    648    -468    -671    -481    45
#
# 570    396    370    243    -463    275    902    -876    385    -616
#
# 93    800    -724    472    -899    668    335    988    -642    -63
#
# -793    231    -663    -574    729    962    -741    232    572    -61
#
# -454    613    -202    335    123    -897    219    -355    -908    77
#
# -660    132    -49    534    177    -530    -704    -43    950    -84
#
# 75    -661    -78    -872    529    -991    -665    173    405    -764
#
# -644    -799    567    -121    -942    -978    933    178    -739    226
#
# -812    -807    442    548    970    -555    617    1000    15    -620
#
# -429    214    461    892    934    -72    970    430    700    950
#
# -984    -762    -266    276    -167    619    -880    730    63    751
#
# -777    226    -907    -11    -732    -738    -403    984    -578    -465
#
# -318    156    -336    626    -435    -436    16    728    -462    -808
#
# 110    -782    392    -595    680    -862    -960    708    -815    -508
#
# 508    143    683    -386    -344    945    -631    -451    767    -490
#
# 501    -489    -666    374    -505    175    750    -438    851    295
#
# 132    489    -616    -330    -112    -338    613    177    817    -992
#
# -733    -381    -380    -648    -341    -951    -779    822    342    182
#
# 580    316    841    78    108    990    975    -582    -526    -564
#
# 610    455    -915    -149    -826    -870    655    109    -332    -950
#
# 45    149    -439    -757    -286    334    225    -861    -446    344
#
# -361    276    286    -204    -648    13    196    724    56    -878
#
# -777    675    -254    -365    -57    -386    -845    163    -916    -186
#
# -796    -500    -401    -185    -784    30    966    -314    492    -373
#
# 760    409    507    -487    864    671    323    -406    355    -778
#
# 494    -296    749    785    535    -78    -487    -178    -399    -301
#
# 796    -27    -455    516    -65    -379    502    798    -697    474
#
# -418    -164    113    147    -691    -384    631    220    -906    551
#
# -940    929    -458    3    -282    -936    738    511    910    -836
#
# -481    -482    882    -296    -829    -138    -215    -369    397    -71
#
# 426    -774    -593    682    -863    -280    637    652    -249    944
#
# -846    -408    -670    -632    373    -632    -233    676    -284    -778
#
# 421    -282    106    -533    977    928    -824    -674    689    -127
#
# -717    974    316    730    -955    399    271    -204    -262    694
#
# 760    -857    -225    -67    -343    415    152    -124    322    -602
#
# -618    503    -634    621    825    -339    681    534    196    162
#
# -396    -652    -793    -776    267    -232    203    -341    337    478
#
# -306    386    -490    -839    983    -212    302    782    -758    -521
#
# -947    -866    -301    -882    429    538    -537    965    9    625
#
# -907    -841    -743    -163    163    -880    -480    385    -35    375
#
# 876    261    822    -655    -470    -103    574    -308    386    680
#
# -328    -766    915    897    -259    376    -963    219    -142    232
#
# -262    -290    -809    -872    -194    -379    -669    816    -447    -962
#
# -429    290    506    162    398    -554    869    -19    -370    270
#
# -302    292    423    -275    136    478    576    -665    432    951
#
# 607    -416    66    -911    770    837    434    -306    -46    983
#
# -214    845    -509    414    31    622    848    824    832    -516
#
# -258    472    42    876    -923    -734    -9    -560    221    998
#
# 541    70    536    -758    300    -6    -704    -986    -645    794
#
# -878    366    -366    330    -813    -543    -980    411    343    -209
#
# 197    989    -576    -678    884    -869    451    -272    -481    -815
#
# 361    -514    -321    314    -93    -360    -629    972    -228    885
#
# -543    -869    862    893    -653    -888    976    -678    -140    582
#
# -697    991    798    -751    -201    -320    -530    732    297    155
#
# -18    -352    -9    -193    -776    421    -33    965    570    -907
#
# -765    150    885    53    527    -630    998    682    -538    427
#
# -198    -427    -866    -608    250    19    -400    -881    252    -994
#
# 306    -15    548    331    -936    -393    -935    744    -738    -474
#
# 945    984    164    -363    184    482    -170    -597    -311    -346
#
# 540    164    -489    265    433    470    -885    309    307    818
#
# -280    -201    106    -168    -235    -47    750    -686    599    308
#
# 835    280    -99    -349    -964    636    -195    613    140    -315
#
# -240    194    -509    989    226    44    224    17    -783    -647
#
# -214    605    -606    -159    48    931    -543    419    -996    343
#
# -880    -111    -176    298    -105    174    87    -375    751    -46
#
# -795    -652    -730    938    -442    -89    -405    540    134    170
#
# -677    785    556    406    -390    -218    -371    9    -923    597
#
# 958    -471    888    -193    89    -638    693    16    -726    -524
#
# 683    624    275    -81    560    -218    -334    635    232    221
#
# -274    -885    595    28    -340    -93    -732    -540    8    -901
#
# 753    408    -203    810    -817    -600    -91    781    107    162
#
# 383    -574    560    336    -197    -5    -635    -939    573    -536
#
# -297    -619    315    885    717    432    -655    -720    467    140
#
# -869    -32    738    -906    -23    -60    352    -693    -708    314
#
# -284    -78    -979    897    -85    885    684    956    798    42
#
# -854    250    955    -827    -650    970    521    410    -591    607
#
# 154    -503    145    367    -555    772    -410    210    -718    -515
#
# 389    -958    -840    96    -467    89    -321    761    224    -322
#
# 336    168    801    168    -586    -241    888    86    -566    190
#
# 929    110    638    751    191    -889    106    996    324    -774
#
# 130    299    569    307    627    186    727    -67    755    -497
#
# -788    392    470    -254    499    84    389    -273    -421    -496
#
# -736    517    457    26    222    -186    -79    -112    598    220
#
# -612    73    376    -695    -808    916    -29    -791    -683    117
#
# 608    993    -62    106    -393    331    -227    -213    -256    667
#
# 596    156    826    -257    -552    -717    -25    883    81    -408
#
# 917    839    -16    -691    -527    181    510    628    1    -341
#
# 919    -284    -411    -387    -788    729    305    212    -290    905
#
# -306    290    7    215    -135    263    -887    -924    -139    -237
#
# -843    -178    -403    951    641    901    106    585    -938    71
#
# 932    -609    378    -951    524    -575    253    -870    473    -394
#
# -229    351    -519    323    736    698    -50    70    634    -291
#
# 744    673    434    -794    362    359    205    -191    110    51
#
# -668    750    101    -242    621    573    592    562    -133    -731
#
# -986    729    924    -336    -850    640    821    320    140    666
